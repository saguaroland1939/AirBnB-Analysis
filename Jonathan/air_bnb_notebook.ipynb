# %% [markdown]
# ### ETL process
#
# #### Extract
# * Import csv file into Pandas DataFrame.
# * Import partners csvs to send to PostgresSQL database
#
# #### Transform
# * Drop columns not required..
# * Add new columns and calculate their values.
# * Drop columns no longer required.
# * Get zip code
# * Drop columns no longer needed.
# * Group data by zip code and get count of airbnbs in area and average price per night
# * Delete missing data and typos.
#
#
# #### Load
#
# * Export all 3 dataframes (zipcode_df, zillow_df, complaints_df) to PostgreSQL database.

# %%
# Import all modules
import pandas as pd
import geopy
from sqlalchemy import create_engine

# %% [markdown]
# #### pull data from air_listings_expanded_chicago.csv and air_listings_chicago.csv

# %%
airbnb_exp_file_path = "../Resources/air_listings_expanded_chicago.csv"
airbnb_exp_df = pd.read_csv(airbnb_exp_file_path)
airbnb_exp_df.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   2384   https://www.airbnb.com/rooms/2384  20201024055553   2020-10-24
# 1   4505   https://www.airbnb.com/rooms/4505  20201024055553   2020-10-24
# 2   7126   https://www.airbnb.com/rooms/7126  20201024055553   2020-10-24
# 3   9811   https://www.airbnb.com/rooms/9811  20201024055553   2020-10-24
# 4  10610  https://www.airbnb.com/rooms/10610  20201024055553   2020-10-24
#
#                                                 name  \
# 0  Hyde Park - Walk to UChicago, 10 min to McCormick
# 1  394 Great Reviews. 127 y/o House. 40 yds to tr...
# 2                Tiny Studio Apartment 94 Walk Score
# 3                      Barbara's Hideaway - Old Town
# 4                   3 Comforts of Cooperative Living
#
#                                          description  \
# 0  Visiting The University of Chicago or attendin...
# 1  We have been closed for quite a while and will...
# 2  A very small studio in a wonderful neighborhoo...
# 3  One-bedroom hideaway tucked into Old Town step...
# 4  The condo is the 2nd floor in a lovely 1912 3-...
#
#                                neighborhood_overview  \
# 0  The apartment is less than one block from beau...
# 1                                                NaN
# 2  Ukrainian Village was just named "Hottest Neig...
# 3  Chicago’s Old Town neighborhood is squeezed be...
# 4  It's a 10 minute walk from the lakefront bike ...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/acf6b3c0-47f2...     2613
# 1  https://a0.muscache.com/pictures/10628083/3543...     5775
# 2  https://a0.muscache.com/pictures/51073/16c81c7...    17928
# 3  https://a0.muscache.com/pictures/37df1935-855c...    33004
# 4  https://a0.muscache.com/pictures/51944609/8d76...     2140
#
#                                   host_url  ... review_scores_communication  \
# 0   https://www.airbnb.com/users/show/2613  ...                        10.0
# 1   https://www.airbnb.com/users/show/5775  ...                        10.0
# 2  https://www.airbnb.com/users/show/17928  ...                        10.0
# 3  https://www.airbnb.com/users/show/33004  ...                         9.0
# 4   https://www.airbnb.com/users/show/2140  ...                         9.0
#
#   review_scores_location review_scores_value                    license  \
# 0                   10.0                10.0               R17000015609
# 1                   10.0                 9.0               R19000037538
# 2                   10.0                10.0  City registration pending
# 3                   10.0                 9.0                    2079260
# 4                   10.0                 9.0  City registration pending
#
#   instant_bookable calculated_host_listings_count  \
# 0                f                              1
# 1                t                              1
# 2                f                              1
# 3                f                              9
# 4                f                              2
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           0
# 1                                           1
# 2                                           1
# 3                                           9
# 4                                           0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            2
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              2.55
# 1                                           0              2.79
# 2                                           0              2.80
# 3                                           0              0.65
# 4                                           0              0.62
#
# [5 rows x 74 columns]

# %%
airbnb_file_path = "../Resources/air listings_chicago.csv"
airbnb_df = pd.read_csv(airbnb_file_path)
airbnb_df.insert(8,"zipcode", '')
airbnb_df
# Out:
#             id                                               name    host_id  \
# 0         2384  Hyde Park - Walk to UChicago, 10 min to McCormick       2613
# 1         4505  394 Great Reviews. 127 y/o House. 40 yds to tr...       5775
# 2         7126                Tiny Studio Apartment 94 Walk Score      17928
# 3         9811                      Barbara's Hideaway - Old Town      33004
# 4        10610                   3 Comforts of Cooperative Living       2140
# ...        ...                                                ...        ...
# 6290  46010835                                   Cozy Two Bedroom  175692579
# 6291  46020831         Live + Work + Stay + Easy | 1BR in Chicago  359234447
# 6292  46022331                            West Ridge private room  156571992
# 6293  46022730    A Family Get Away -All the Amenities to Stay IN  291691868
# 6294  46028175  IDEAL FOR LONG STAYS 2 BEDROOM 2 BATH WiFi Par...    3965428
#
#               host_name  neighbourhood_group    neighbourhood  latitude  \
# 0               Rebecca                  NaN        Hyde Park  41.78790
# 1      Craig & Kathleen                  NaN   South Lawndale  41.85495
# 2                 Sarah                  NaN        West Town  41.90289
# 3           At Home Inn                  NaN     Lincoln Park  41.91769
# 4                  Lois                  NaN        Hyde Park  41.79612
# ...                 ...                  ...              ...       ...
# 6290            Deborah                  NaN          Douglas  41.83283
# 6291                Kia                  NaN  Near North Side  41.89111
# 6292             Bogdan                  NaN       West Ridge  42.00124
# 6293  Michael And Angel                  NaN        West Town  41.90518
# 6294                Rob                  NaN   Jefferson Park  41.97185
#
#       longitude zipcode        room_type  price  minimum_nights  \
# 0    -87.587800             Private room     65               2
# 1    -87.696960          Entire home/apt    105               2
# 2    -87.681820          Entire home/apt     60               2
# 3    -87.637880          Entire home/apt     66               4
# 4    -87.592610             Private room     22               1
# ...         ...     ...              ...    ...             ...
# 6290 -87.618630          Entire home/apt    110               3
# 6291 -87.622050          Entire home/apt    116              33
# 6292 -87.681430             Private room     21               1
# 6293 -87.664358          Entire home/apt    306               2
# 6294 -87.766052          Entire home/apt     96              60
#
#       number_of_reviews last_review  reviews_per_month  \
# 0                   180  2020-10-03               2.55
# 1                   395  2020-07-14               2.79
# 2                   385  2020-09-14               2.80
# 3                    52  2020-09-29               0.65
# 4                    45  2020-09-15               0.62
# ...                 ...         ...                ...
# 6290                  0         NaN                NaN
# 6291                  0         NaN                NaN
# 6292                  0         NaN                NaN
# 6293                  0         NaN                NaN
# 6294                  0         NaN                NaN
#
#       calculated_host_listings_count  availability_365
# 0                                  1               359
# 1                                  1               187
# 2                                  1               347
# 3                                  9               310
# 4                                  2               201
# ...                              ...               ...
# 6290                               2               355
# 6291                              54               277
# 6292                               1               263
# 6293                               1                83
# 6294                              74               365
#
# [6295 rows x 17 columns]

# %% [markdown]
# #### defined function for finding the zipcode from a set of latitude and longitude values
# runtime = 1h 14m

# %%
def get_zipcode(lat_field, lon_field, df, index):
    try:
        geolocator = geopy.Nominatim(user_agent='air_bnb_review', timeout = 10)
        location = geolocator.reverse((lat_field, lon_field))
        df.at[index, "zipcode"] = location.raw["address"]["postcode"]
    except (KeyError):
        pass
    return

# %% [markdown]
# #### call to function to get data  and export to dataframe

# %%
for index, row in airbnb_df.iterrows():
    get_zipcode(row["latitude"], row["longitude"], airbnb_df, index)

# %%
airbnb_df[airbnb_df["zipcode"] ==""]
# Out:
#             id                                               name    host_id  \
# 130    1516154   Best Location Millennium Park Extended Stay POOL    3965428
# 207    2661465         GREAT LOCATION SPECTACULAR VIEWS + BALCONY    3965428
# 333    4503332                  Near The Loop and McCormick Place   20059524
# 432    6156931  ★MUST LOCATION 2 BEDROOMS + 2 BATH FANTASTIC V...    3965428
# 446    6375348     Convenient Quiet Oasis near Downtown and Beach   16050215
# ...        ...                                                ...        ...
# 6233  45880617         Live + Work + Stay + Easy | 1BR in Chicago  359234447
# 6244  45909330         Live + Work + Stay + Easy | 2BR in Chicago  359234447
# 6266  45973926         Live + Work + Stay + Easy | 2BR in Chicago  359234447
# 6269  45976728         Live + Work + Stay + Easy | 3BR in Chicago  359234447
# 6291  46020831         Live + Work + Stay + Easy | 1BR in Chicago  359234447
#
#                      host_name  neighbourhood_group    neighbourhood  \
# 130                        Rob                  NaN             Loop
# 207                        Rob                  NaN             Loop
# 333   (Email hidden by Airbnb)                  NaN    Armour Square
# 432                        Rob                  NaN             Loop
# 446                    Terryon                  NaN          Douglas
# ...                        ...                  ...              ...
# 6233                       Kia                  NaN  Near North Side
# 6244                       Kia                  NaN  Near North Side
# 6266                       Kia                  NaN  Near North Side
# 6269                       Kia                  NaN  Near North Side
# 6291                       Kia                  NaN  Near North Side
#
#       latitude  longitude zipcode        room_type  price  minimum_nights  \
# 130   41.88642  -87.61695          Entire home/apt     60              31
# 207   41.88618  -87.61888          Entire home/apt    120              31
# 333   41.85586  -87.63569          Entire home/apt    100               1
# 432   41.88626  -87.61632          Entire home/apt    175              60
# 446   41.83240  -87.61058             Private room     50               3
# ...        ...        ...     ...              ...    ...             ...
# 6233  41.89111  -87.62205          Entire home/apt    128              33
# 6244  41.89111  -87.62205          Entire home/apt    160              33
# 6266  41.89111  -87.62205          Entire home/apt    163              33
# 6269  41.89111  -87.62205          Entire home/apt    229              33
# 6291  41.89111  -87.62205          Entire home/apt    116              33
#
#       number_of_reviews last_review  reviews_per_month  \
# 130                  18  2015-08-16               0.21
# 207                  25  2018-06-29               0.32
# 333                  86  2020-03-15               1.31
# 432                  14  2017-08-31               0.21
# 446                 184  2020-10-11               2.81
# ...                 ...         ...                ...
# 6233                  0         NaN                NaN
# 6244                  0         NaN                NaN
# 6266                  0         NaN                NaN
# 6269                  0         NaN                NaN
# 6291                  0         NaN                NaN
#
#       calculated_host_listings_count  availability_365
# 130                               74               365
# 207                               74               365
# 333                                3                87
# 432                               74               364
# 446                                1               250
# ...                              ...               ...
# 6233                              54               327
# 6244                              54               331
# 6266                              54               267
# 6269                              54               304
# 6291                              54               277
#
# [63 rows x 17 columns]

# %% [markdown]
# ## clean data to find only the relevent zipcodes

# %%
airbnb_full_df = airbnb_df[airbnb_df["zipcode"] != ""]
try:
    airbnb_full_df = pd.to_numeric(airbnb_full_df["zipcode"])
    airbnb_full_df = airbnb_full_df[airbnb_full_df["zipcode"] <=70000]
    airbnb_full_df = airbnb_full_df[airbnb_full_df["zipcode"] >=60000]
except(ValueError):
    pass

# %%
grouped_air_df = airbnb_full_df.groupby("zipcode").agg(count=('id', 'size'), mean=('price', 'mean')).reset_index()
pd.set_option('display.max_rows', 100)
grouped_air_df = grouped_air_df.rename(columns ={"zipcode": "zip_code", "count": "air_bnb_count", "mean": "avg_air_bnb_cost"})
grouped_air_df
# Out:
#        zip_code  air_bnb_count  avg_air_bnb_cost
# 0          2300              1         45.000000
# 1         46394              1         50.000000
# 2         60018              1         39.000000
# 3         60171              1        107.000000
# 4         60302             37        143.297297
# 5         60304              1        350.000000
# 6         60402              3         69.666667
# 7         60453              1         35.000000
# 8           606              8         85.750000
# 9         60601            111        456.423423
# 10        60602             24        153.125000
# 11        60603              7        137.857143
# 12        60604             21        156.619048
# 13        60605            199        165.793970
# 14        60606             65        148.984615
# 15        60607            120        121.725000
# 16        60608            245        111.383673
# 17        60609             53         92.811321
# 18        60610            215        206.586047
# 19        60611            286        177.363636
# 20        60612            189        139.899471
# 21        60613            228        255.337719
# 22        60614            303        181.066007
# 23        60615            120        111.358333
# 24   60615-5299              1         70.000000
# 25        60616            220        130.918182
# 26        60617             59         71.864407
# 27  60617:60649              2         85.000000
# 28        60618            266        159.725564
# 29   60618-9997              3         88.333333
# 30        60619             39         96.897436
# 31        60620             22        114.363636
# 32        60621             28        106.928571
# 33        60622            366        160.912568
# 34   60622-4580              5        162.800000
# 35       606226             19         86.578947
# 36        60623             77        140.714286
# 37        60624             65         72.246154
# 38        60625            218        105.495413
# 39        60626             92        123.815217
# 40        60628             22         99.318182
# 41        60629             25         53.440000
# 42        60630             93         88.741935
# 43        60631             11         53.636364
# 44        60632             29         94.172414
# 45        60633              3        124.666667
# 46        60634             67         87.358209
# 47        60636              5        331.800000
# 48        60637            152         75.657895
# 49        60638             11         89.727273
# 50        60639             54        108.685185
# 51        60640            145        152.275862
# 52        60641             84         75.595238
# 53        60642             61        266.672131
# 54        60643             17         85.352941
# 55        60644             60        110.866667
# 56        60645            115         80.791304
# 57        60646             43        119.511628
# 58        60647            364        135.063187
# 59       606476             56        330.982143
# 60        60649             56         85.178571
# 61        60651             78        133.000000
# 62        60652             12         63.416667
# 63        60653            120        134.541667
# 64        60654            158        189.531646
# 65   60654-5799              1       1142.000000
# 66        60655              3         52.666667
# 67        60656             19         82.368421
# 68        60657            341        194.759531
# 69        60659             58        112.672414
# 70        60660            116        108.206897
# 71        60661             72        227.472222
# 72         6069              3         52.666667
# 73        60696              3        290.000000
# 74        60706              1         65.000000
# 75        60707              6         82.166667
# 76        60805              1        150.000000
# 77        60827              2         22.000000
# 78       690639              8        190.625000
# 79         9020             27        105.222222
# 80        90615              8         92.250000

# %%
filtrered_df = grouped_air_df[grouped_air_df['zip_code'].str.len() == 5]
filtered_df = filtrered_df[filtrered_df['zip_code'] != "46394"]
filtered_df = filtered_df[filtrered_df['zip_code'] != "90615"]
air_bnb_df = filtered_df.set_index('zip_code')
air_bnb_df
# Out:
# C:\Users\staff\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
#           air_bnb_count  avg_air_bnb_cost
# zip_code
# 60018                 1         39.000000
# 60171                 1        107.000000
# 60302                37        143.297297
# 60304                 1        350.000000
# 60402                 3         69.666667
# 60453                 1         35.000000
# 60601               111        456.423423
# 60602                24        153.125000
# 60603                 7        137.857143
# 60604                21        156.619048
# 60605               199        165.793970
# 60606                65        148.984615
# 60607               120        121.725000
# 60608               245        111.383673
# 60609                53         92.811321
# 60610               215        206.586047
# 60611               286        177.363636
# 60612               189        139.899471
# 60613               228        255.337719
# 60614               303        181.066007
# 60615               120        111.358333
# 60616               220        130.918182
# 60617                59         71.864407
# 60618               266        159.725564
# 60619                39         96.897436
# 60620                22        114.363636
# 60621                28        106.928571
# 60622               366        160.912568
# 60623                77        140.714286
# 60624                65         72.246154
# 60625               218        105.495413
# 60626                92        123.815217
# 60628                22         99.318182
# 60629                25         53.440000
# 60630                93         88.741935
# 60631                11         53.636364
# 60632                29         94.172414
# 60633                 3        124.666667
# 60634                67         87.358209
# 60636                 5        331.800000
# 60637               152         75.657895
# 60638                11         89.727273
# 60639                54        108.685185
# 60640               145        152.275862
# 60641                84         75.595238
# 60642                61        266.672131
# 60643                17         85.352941
# 60644                60        110.866667
# 60645               115         80.791304
# 60646                43        119.511628
# 60647               364        135.063187
# 60649                56         85.178571
# 60651                78        133.000000
# 60652                12         63.416667
# 60653               120        134.541667
# 60654               158        189.531646
# 60655                 3         52.666667
# 60656                19         82.368421
# 60657               341        194.759531
# 60659                58        112.672414
# 60660               116        108.206897
# 60661                72        227.472222
# 60696                 3        290.000000
# 60706                 1         65.000000
# 60707                 6         82.166667
# 60805                 1        150.000000
# 60827                 2         22.000000

# %% [markdown]
# # Load
#
# Create engine connecting to Postgress SQL and send dataframes

# %%
connection_string = "postgres:R3ds0x916!@localhost:5432/chicago_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# test to see if all tables are found in the postgresSQl Database
engine.table_names()
# Out:
# ['air_bnb', 'zillow', 'complaints']

# %% [markdown]
# #### Export air_bnb_df to Sql

# %%
air_bnb_df.to_sql(name='air_bnb', con=engine, if_exists='append', index=True)

# %%
#
zillow_df = pd.read_csv("../Abraham/zillow_zip.csv")
zillow_df = zillow_df[["zip_code", "avg_price_per_sq_ft", "avg_price"]]
zillow_df = zillow_df.rename(columns={"avg_price_per_sq_ft" : "zillow_avg_price_per_sq_ft", "avg_price": "zillow_avg_price"})
zillow_df.head()
# Out:
#    zip_code  zillow_avg_price_per_sq_ft  zillow_avg_price
# 0     60608                  225.082960     286108.757576
# 1     60614                  456.706207     577682.778689
# 2     60615                  140.517034     181651.077778
# 3     60617                   77.808295      88679.166667
# 4     60618                  295.810959     417163.265306

# %% [markdown]
# #### Export zillow_df to Sql

# %%
zillow_df.to_sql(name='zillow', con=engine, if_exists='append', index=False)

# %%
complaints_df = pd.read_csv("../Veronica/Noise_complaint_counts_by_zip.csv")
complaints_df.head()
# Out:
#    zip_code  num_complaints
# 0     60601               7
# 1     60602               4
# 2     60603               4
# 3     60604               1
# 4     60605              54

# %% [markdown]
# #### Export complaints_df to Sql

# %%
complaints_df.to_sql(name='complaints', con=engine, if_exists='append', index=False)
